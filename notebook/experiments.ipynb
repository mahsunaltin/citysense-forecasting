# %% [markdown]
# # Install Libraries

# %%
# Since Colab already includes most required libraries, we only need to import the following.
# !pip install sktime
# !pip install einops==0.8.0
# !pip install local-attention==1.9.14
# !pip install patool==1.12
# !pip install reformer-pytorch==1.4.4
# !pip install numpy==1.26.4

# %% [markdown]
# # Clone GitHub Repo

# %%
# %cd /content
# %rm -r /content/citysense-forecasting/

# %%
token = "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"
repo_url = "github.com/mahsunaltin/citysense-forecasting.git"

branch_name = "melbourne-datasets"
#commit_name = "3d557dfece2b2707b1917cb071f8793af6d36660"

# !git clone -b {branch_name} https://{token}:x-oauth-basic@{repo_url}

#%cd citysense-forecasting
#!git checkout {commit_name}

#!git clone https://{token}:x-oauth-basic@{repo_url}

# %% [markdown]
# # Run Experiments

# %%
# Change directory
# %cd /content/citysense-forecasting

# %% [markdown]
# ## Argyle Square Experiments

# %%
# Argyle Square - TimeMixer
# !bash ./scripts/Argyle_square_script/TimeMixer.sh

# %%
# Argyle Square - RAFT
# !bash ./scripts/Argyle_square_script/RAFT.sh

# %%
# Argyle Square - WPMixer
# !bash ./scripts/Argyle_square_script/WPMixer.sh

# %% [markdown]
# ## ETT Experiments

# %%
# ETTh1 - TimeMixer
# !bash ./scripts/ETT_script/TimeMixer_ETTh1.sh

# %%
# ETTh1 - RAFT
# !bash ./scripts/ETT_script/RAFT_ETTh1.sh

# %%
# ETTh1 - WPMixer
# !bash ./scripts/ETT_script/WPMixer_ETTh1.sh

# %%
# ETTh2 - TimeMixer
# !bash ./scripts/ETT_script/TimeMixer_ETTh2.sh

# %%
# ETTh2 - RAFT
# !bash ./scripts/ETT_script/RAFT_ETTh2.sh

# %%
# ETTh2 - WPMixer
# !bash ./scripts/ETT_script/WPMixer_ETTh2.sh

# %%
# ETTm1 - TimeMixer
# !bash ./scripts/ETT_script/TimeMixer_ETTm1.sh

# %%
# ETTm1 - RAFT
# !bash ./scripts/ETT_script/RAFT_ETTm1.sh

# %%
# ETTm1 - WPMixer
# !bash ./scripts/ETT_script/WPMixer_ETTm1.sh

# %%
# ETTm2 - TimeMixer
# !bash ./scripts/ETT_script/TimeMixer_ETTm2.sh

# %%
# ETTm2 - RAFT
# !bash ./scripts/ETT_script/RAFT_ETTm2.sh

# %%
# ETTm2 - WPMixer
# !bash ./scripts/ETT_script/WPMixer_ETTm2.sh

# %% [markdown]
# ## Microclimate Sensors Experiments

# %%
# Microclimate Sensors - TimeMixer
# !bash ./scripts/Microclimate_sensors_script/TimeMixer.sh

# %%
# Microclimate Sensors - RAFT
# !bash ./scripts/Microclimate_sensors_script/RAFT.sh

# %%
# Microclimate Sensors - WPMixer
# !bash ./scripts/Microclimate_sensors_script/WPMixer.sh

# %% [markdown]
# ## Pedestrian Experiments

# %%
# Pedestrian - TimeMixer
# !bash ./scripts/Pedestrian_script/TimeMixer.sh

# %%
# Pedestrian - RAFT
# !bash ./scripts/Pedestrian_script/RAFT.sh

# %%
# Pedestrian - WPMixer
# !bash ./scripts/Pedestrian_script/WPMixer.sh
